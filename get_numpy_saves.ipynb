# %%
import os
import pydicom
import numpy as np
from pathlib import Path
from DicomToNumpyClass import DicomToNumpy

# %%
processor = DicomToNumpy("Brain_Stroke_CT_Dataset")

# %%
processor.generate_files()
# Out:
# Iniciando procesamiento desde: Brain_Stroke_CT_Dataset
# Destino: Brain_Stroke_CT_Dataset_numpy
#
# Error leyendo 10187.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 10690.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 11380.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 11956.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 13105.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 13521.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 13625.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 14173.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 14863.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 15211.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 15726.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 15753.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 15949.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1
# Error leyendo 16737.dcm: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# 	pylibjpeg - requires pylibjpeg>=2.0 and pylibjpeg-libjpeg>=2.1

# %%
processor.summary()
# Out:
# --------------------------------------------------
# RESUMEN DEL PROCESAMIENTO
# --------------------------------------------------
# Clase: Bleeding
#   - Imágenes guardadas (512x512): 1070
#   - Imágenes descartadas (otro tamaño): 23
#   - Shape final del array: (1070, 512, 512)
#   - Guardado en: Brain_Stroke_CT_Dataset_numpy\Bleeding.npy
# ..............................
# Clase: Ischemia
#   - Imágenes guardadas (512x512): 1076
#   - Imágenes descartadas (otro tamaño): 40
#   - Shape final del array: (1076, 512, 512)
#   - Guardado en: Brain_Stroke_CT_Dataset_numpy\Ischemia.npy
# ..............................
# Clase: Normal
#   - Imágenes guardadas (512x512): 4242
#   - Imágenes descartadas (otro tamaño): 185
#   - Shape final del array: (4242, 512, 512)
#   - Guardado en: Brain_Stroke_CT_Dataset_numpy\Normal.npy
# ..............................
# TOTAL IMÁGENES PROCESADAS: 6388
# --------------------------------------------------

# %%
dataset = processor.get_data()
# Out:
# Cargando datos en memoria...
#   -> Cargado Bleeding: (1070, 512, 512)
#   -> Cargado Ischemia: (1076, 512, 512)
#   -> Cargado Normal: (4242, 512, 512)
