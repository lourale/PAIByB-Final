# %%
import sys
sys.path.append("..")

# %%
from DicomToNumpyClass import DicomToNumpy
from preprocessor import CTManager, CTProcessor

# %%
processor = DicomToNumpy("../Brain_Stroke_CT_Dataset")
subdataset = processor.get_subset(limit = 20) # tomo solo las 1000 primeras imágenes
# Out:
# Cargando subconjunto de datos (Primeras 20 imágenes)...
#   -> Cargado Bleeding: (20, 512, 512)
#   -> Cargado Ischemia: (20, 512, 512)
#   -> Cargado Normal: (20, 512, 512)

# %%
subdataset_filtered = CTManager.process_batch(subdataset)

# %%
for i in range(len(subdataset_filtered['Normal'])):
    image = subdataset_filtered['Normal'][i]
    image.plot()
